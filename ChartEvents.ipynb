# %%
import pandas as pd
import numpy as np
import os

# %%
# %load_ext memory_profiler

# %%
#file$ 4. This is  32GB file, 
dfCHARTEVENTS = pd.read_csv(r'C:\Users\mkhan74\Documents\MIMICiiiDup\CHARTEVENTS.csv', nrows=1048576)
#dfCHARTEVENTS = pd.read_csv(r'C:\Users\mkhan74\Documents\MIMICiiiDup\CHARTEVENTS.csv')

# %%
#https://timothymonteath.com/articles/monitoring_memory_usage/
# %memit
# Out:
# peak memory: 218.17 MiB, increment: 0.41 MiB

# %%
dfCHARTEVENTS.head(50)
# Out:
#     ROW_ID  SUBJECT_ID  HADM_ID  ICUSTAY_ID  ITEMID            CHARTTIME  \
# 0      788          36   165660    241249.0  223834  2134-05-12 12:00:00
# 1      789          36   165660    241249.0  223835  2134-05-12 12:00:00
# 2      790          36   165660    241249.0  224328  2134-05-12 12:00:00
# 3      791          36   165660    241249.0  224329  2134-05-12 12:00:00
# 4      792          36   165660    241249.0  224330  2134-05-12 12:00:00
# 5      793          36   165660    241249.0  224331  2134-05-12 12:00:00
# 6      794          36   165660    241249.0  224332  2134-05-12 12:00:00
# 7      795          36   165660    241249.0  224663  2134-05-12 12:00:00
# 8      796          36   165660    241249.0  224665  2134-05-12 12:00:00
# 9      797          36   165660    241249.0  220224  2134-05-12 12:35:00
# 10     798          36   165660    241249.0  220235  2134-05-12 12:35:00
# 11     799          36   165660    241249.0  223830  2134-05-12 12:35:00
# ...

# %%
dfCHARTEVENTS.tail(50)
# Out:
#           ROW_ID  SUBJECT_ID  HADM_ID  ICUSTAY_ID  ITEMID  \
# 1048526  1014042       10694   138159    294193.0  220052
# 1048527  1014043       10694   138159    294193.0  220074
# 1048528  1014044       10694   138159    294193.0  220210
# 1048529  1014045       10694   138159    294193.0  220292
# 1048530  1014046       10694   138159    294193.0  220293
# 1048531  1014047       10694   138159    294193.0  220339
# 1048532  1014048       10694   138159    294193.0  223835
# 1048533  1014049       10694   138159    294193.0  223873
# 1048534  1014050       10694   138159    294193.0  223874
# 1048535  1014051       10694   138159    294193.0  223876
# 1048536  1014052       10694   138159    294193.0  224685
# 1048537  1014053       10694   138159    294193.0  224686
# 1048538  1014054       10694   138159    294193.0  224687
# 1048539  1014055       10694   138159    294193.0  224689
# 1048540  1014056       10694   138159    294193.0  224690
# ...

# %%
#https://timothymonteath.com/articles/monitoring_memory_usage/
# %memit
# Out:
# peak memory: 219.32 MiB, increment: 0.00 MiB

# %%
dfCHARTEVENTS.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1048576 entries, 0 to 1048575
# Data columns (total 15 columns):
#  #   Column        Non-Null Count    Dtype
# ---  ------        --------------    -----
#  0   ROW_ID        1048576 non-null  int64
#  1   SUBJECT_ID    1048576 non-null  int64
#  2   HADM_ID       1048576 non-null  int64
#  3   ICUSTAY_ID    1048119 non-null  float64
#  4   ITEMID        1048576 non-null  int64
#  5   CHARTTIME     1048576 non-null  object
#  6   STORETIME     848102 non-null   object
#  7   CGID          848102 non-null   float64
#  8   VALUE         1048576 non-null  float64
#  9   VALUENUM      1048576 non-null  float64
#  10  VALUEUOM      986910 non-null   object
#  11  WARNING       1048576 non-null  int64
#  12  ERROR         1048576 non-null  int64
#  13  RESULTSTATUS  0 non-null        float64
#  14  STOPPED       0 non-null        float64
# dtypes: float64(6), int64(6), object(3)
# memory usage: 120.0+ MB

# %%
dfCHARTEVENTS.drop('RESULTSTATUS',axis=1,inplace=True)
dfCHARTEVENTS.drop('STOPPED',axis=1,inplace=True)

# %%
dfCHARTEVENTS.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1048576 entries, 0 to 1048575
# Data columns (total 13 columns):
#  #   Column      Non-Null Count    Dtype
# ---  ------      --------------    -----
#  0   ROW_ID      1048576 non-null  int64
#  1   SUBJECT_ID  1048576 non-null  int64
#  2   HADM_ID     1048576 non-null  int64
#  3   ICUSTAY_ID  1048119 non-null  float64
#  4   ITEMID      1048576 non-null  int64
#  5   CHARTTIME   1048576 non-null  object
#  6   STORETIME   848102 non-null   object
#  7   CGID        848102 non-null   float64
#  8   VALUE       1048576 non-null  float64
#  9   VALUENUM    1048576 non-null  float64
#  10  VALUEUOM    986910 non-null   object
#  11  WARNING     1048576 non-null  int64
#  12  ERROR       1048576 non-null  int64
# dtypes: float64(4), int64(6), object(3)
# memory usage: 104.0+ MB
